# %%
import re
output_dir = "\analysis"

# %%
# Read the log.mv file and print its contents
with open('log.yPlus', 'r') as file:
    log_contents = file.read()

print(log_contents)
# Out:
# /*---------------------------------------------------------------------------*\
# | =========                 |                                                 |
# | \\      /  F ield         | OpenFOAM: The Open Source CFD Toolbox           |
# |  \\    /   O peration     | Version:  2406                                  |
# |   \\  /    A nd           | Website:  www.openfoam.com                      |
# |    \\/     M anipulation  |                                                 |
# \*---------------------------------------------------------------------------*/
# Build  : 630d60de3b-20240620 OPENFOAM=2406 version=v2406
# Arch   : "LSB;label=32;scalar=64"
# Exec   : overInterDyMFoam -postProcess -func yPlus
# Date   : Feb 11 2025
# Time   : 11:03:41
# Host   : Coastal-song
# PID    : 11961
# I/O    : uncollated
# Case   : /home/song/OpenFOAM/song-v2406/run/pukyung_0124_9/background
# nProcs : 1
# trapFpe: Floating point exception trapping enabled (FOAM_SIGFPE).
# fileModificationChecking : Monitoring run-time modified files using timeStampMaster (fileModificationSkew 5, maxFileModificationPolls 20)
# allowSystemOperations : Allowing user-supplied system call operations
#
# // * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * //
# Create time
#
# Create mesh for time = 0
#
#
# PIMPLE: no residual control data found. Calculations will employ 2 corrector loops
#
# Time = 0
# Reading field p_rgh
#
# Reading field U
#
# Reading/calculating face flux field phi
#
# inverseDistance : detected 2 mesh regions
#     zone:0 nCells:92000  voxels:(100 400 1) bb:(-2 -8.6 -0.1) (2 7 0.1)
#     zone:1 nCells:5568  voxels:(100 400 1) bb:(-2 -8.6 -0.1) (2 7 0.1)
# Overset analysis : nCells : 97568
#     calculated   : 88536
#     interpolated : 932 (from local:932  mixed local/remote:0  remote:0)
#     hole         : 8100
#
# Creating cellMask field to block out hole cells
#
# --> FOAM Warning :
#     From bool Foam::oversetPolyPatch::master() const
#     in file oversetPolyPatch/oversetPolyPatch.C at line 145
#     The master overset patch is not the first patch. Generally the first patch should be an overset patch to guarantee consistent operation.
# Creating interpolatedCells field
#
# Reading transportProperties
#
# Selecting incompressible transport model Newtonian
# Selecting incompressible transport model Newtonian
# Selecting turbulence model type RAS
# Selecting RAS turbulence model kEpsilon
# RAS
# {
#     RASModel        kEpsilon;
#     turbulence      on;
#     printCoeffs     on;
#     Cmu             0.09;
#     C1              1.44;
#     C2              1.92;
#     C3              0;
#     sigmak          1;
#     sigmaEps        1.3;
# }
#
#
# Reading g
#
# Reading hRef
# Calculating field g.h
#
# No MRF models present
#
# yPlus yPlus write:
#     writing field yPlus
#     patch left_1 y+ : min = 92.5207, max = 1369.306, average = 194.6636
#     patch bottom_1 y+ : min = 1369.306, max = 1369.306, average = 1369.306
#     patch right_3 y+ : min = 92.5207, max = 1369.306, average = 194.6636
#     patch bottom_3 y+ : min = 1369.306, max = 1369.306, average = 1369.306
#     patch left_4 y+ : min = 1369.306, max = 1369.306, average = 1369.306
#     patch right_4 y+ : min = 1369.306, max = 1369.306, average = 1369.306
#     patch bottom_4 y+ : min = 1369.306, max = 1369.306, average = 1369.306
#     patch movingObject y+ : min = 1369.306, max = 1369.306, average = 1369.306
#
# Time = 0.01
# Reading field p_rgh
#
# Reading field U
#
# Reading/calculating face flux field phi
#
# Creating cellMask field to block out hole cells
#
# Creating interpolatedCells field
#
# Reading transportProperties
#
# Selecting incompressible transport model Newtonian
# Selecting incompressible transport model Newtonian
# Selecting turbulence model type RAS
# Selecting RAS turbulence model kEpsilon
# RAS
# {
#     RASModel        kEpsilon;
#     turbulence      on;
#     printCoeffs     on;
#     Cmu             0.09;
#     C1              1.44;
#     C2              1.92;
#     C3              0;
#     sigmak          1;
#     sigmaEps        1.3;
# }
#
#
# Reading g
#
# Reading hRef
# Calculating field g.h
#
# No MRF models present
#
# yPlus yPlus write:
#     writing field yPlus
#     patch left_1 y+ : min = 91.84099, max = 1361.929, average = 193.461
#     patch bottom_1 y+ : min = 1358.579, max = 2049.638, average = 1397.908
#     patch right_3 y+ : min = 91.84099, max = 1361.929, average = 193.461
#     patch bottom_3 y+ : min = 1358.579, max = 2049.638, average = 1397.908
#     patch left_4 y+ : min = 1358.384, max = 3277.369, average = 1506.004
#     patch right_4 y+ : min = 1358.384, max = 3277.369, average = 1506.004
#     patch bottom_4 y+ : min = 1358.384, max = 1358.419, average = 1358.385
#     patch movingObject y+ : min = 1373.451, max = 8736.345, average = 2187.555
#
# Time = 0.02
# Reading field p_rgh
#
# Reading field U
#
# Reading/calculating face flux field phi
#
# Creating cellMask field to block out hole cells
#
# Creating interpolatedCells field
#
# Reading transportProperties
#
# Selecting incompressible transport model Newtonian
# Selecting incompressible transport model Newtonian
# Selecting turbulence model type RAS
# Selecting RAS turbulence model kEpsilon
# RAS
# {
#     RASModel        kEpsilon;
#     turbulence      on;
#     printCoeffs     on;
#     Cmu             0.09;
#     C1              1.44;
#     C2              1.92;
#     C3              0;
#     sigmak          1;
#     sigmaEps        1.3;
# }
#
#
# Reading g
#
# Reading hRef
# Calculating field g.h
#
# No MRF models present
#
# yPlus yPlus write:
#     writing field yPlus
#     patch left_1 y+ : min = 91.17677, max = 1355.649, average = 192.3853
#     patch bottom_1 y+ : min = 1347.738, max = 2321.949, average = 1420.674
#     patch right_3 y+ : min = 91.17677, max = 1355.649, average = 192.3853
#     patch bottom_3 y+ : min = 1347.738, max = 2321.949, average = 1420.674
#     patch left_4 y+ : min = 1347.574, max = 6973.618, average = 1743.509
#     patch right_4 y+ : min = 1347.574, max = 6973.615, average = 1743.509
#     patch bottom_4 y+ : min = 1347.574, max = 1347.703, average = 1347.577
#     patch movingObject y+ : min = 1360.398, max = 18116.2, average = 3613.742
#
# Time = 0.03
# Reading field p_rgh
#
# Reading field U
#
# Reading/calculating face flux field phi
#
# Creating cellMask field to block out hole cells
#
# Creating interpolatedCells field
#
# Reading transportProperties
#
# Selecting incompressible transport model Newtonian
# Selecting incompressible transport model Newtonian
# Selecting turbulence model type RAS
# Selecting RAS turbulence model kEpsilon
# RAS
# {
#     RASModel        kEpsilon;
#     turbulence      on;
#     printCoeffs     on;
#     Cmu             0.09;
#     C1              1.44;
#     C2              1.92;
#     C3              0;
#     sigmak          1;
#     sigmaEps        1.3;
# }
#
#
# Reading g
#
# Reading hRef
# Calculating field g.h
#
# No MRF models present
#
# yPlus yPlus write:
#     writing field yPlus
#     patch left_1 y+ : min = 90.53168, max = 1349.808, average = 191.3821
#     patch bottom_1 y+ : min = 1336.734, max = 2338.692, average = 1433.082
#     patch right_3 y+ : min = 90.53167, max = 1349.808, average = 191.3821
#     patch bottom_3 y+ : min = 1336.734, max = 2338.692, average = 1433.082
#     patch left_4 y+ : min = 1336.885, max = 13472.21, average = 2122.054
#     patch right_4 y+ : min = 1336.885, max = 13472.21, average = 2122.055
#     patch bottom_4 y+ : min = 1336.885, max = 1337.154, average = 1336.891
#     patch movingObject y+ : min = 1345.458, max = 24179.97, average = 5114.33
#
# Time = 0.04
# Reading field p_rgh
#
# Reading field U
#
# Reading/calculating face flux field phi
#
# Creating cellMask field to block out hole cells
#
# Creating interpolatedCells field
#
# Reading transportProperties
#
# Selecting incompressible transport model Newtonian
# Selecting incompressible transport model Newtonian
# Selecting turbulence model type RAS
# Selecting RAS turbulence model kEpsilon
# RAS
# {
#     RASModel        kEpsilon;
#     turbulence      on;
#     printCoeffs     on;
#     Cmu             0.09;
#     C1              1.44;
#     C2              1.92;
#     C3              0;
#     sigmak          1;
#     sigmaEps        1.3;
# }
#
#
# Reading g
#
# Reading hRef
# Calculating field g.h
#
# No MRF models present
#
# yPlus yPlus write:
#     writing field yPlus
#     patch left_1 y+ : min = 89.88203, max = 1343.444, average = 190.3475
#     patch bottom_1 y+ : min = 1325.701, max = 2208.876, average = 1433.904
#     patch right_3 y+ : min = 89.88202, max = 1343.444, average = 190.3474
#     patch bottom_3 y+ : min = 1325.701, max = 2208.876, average = 1433.904
#     patch left_4 y+ : min = 1326.321, max = 14289.14, average = 2409.908
#     patch right_4 y+ : min = 1326.322, max = 14289.14, average = 2409.908
#     patch bottom_4 y+ : min = 1326.321, max = 1326.769, average = 1326.333
#     patch movingObject y+ : min = 1331.197, max = 33950.81, average = 6835.519
#
# Time = 0.05
# Reading field p_rgh
#
# Reading field U
#
# Reading/calculating face flux field phi
#
# Creating cellMask field to block out hole cells
#
# Creating interpolatedCells field
#
# Reading transportProperties
#
# Selecting incompressible transport model Newtonian
# Selecting incompressible transport model Newtonian
# Selecting turbulence model type RAS
# Selecting RAS turbulence model kEpsilon
# RAS
# {
#     RASModel        kEpsilon;
#     turbulence      on;
#     printCoeffs     on;
#     Cmu             0.09;
#     C1              1.44;
#     C2              1.92;
#     C3              0;
#     sigmak          1;
#     sigmaEps        1.3;
# }
#
#
# Reading g
#
# Reading hRef
# Calculating field g.h
#
# No MRF models present
#
# yPlus yPlus write:
#     writing field yPlus
#     patch left_1 y+ : min = 89.25063, max = 1336.024, average = 189.2389
#     patch bottom_1 y+ : min = 1314.808, max = 2046.577, average = 1426.212
#     patch right_3 y+ : min = 89.25063, max = 1336.024, average = 189.2389
#     patch bottom_3 y+ : min = 1314.808, max = 2046.577, average = 1426.212
#     patch left_4 y+ : min = 1315.889, max = 15547.64, average = 2615.362
#     patch right_4 y+ : min = 1315.889, max = 15547.63, average = 2615.362
#     patch bottom_4 y+ : min = 1315.888, max = 1316.543, average = 1315.905
#     patch movingObject y+ : min = 1323.072, max = 39574.62, average = 8106.405
#
# Time = 0.06
# Reading field p_rgh
#
# Reading field U
#
# Reading/calculating face flux field phi
#
# Creating cellMask field to block out hole cells
#
# Creating interpolatedCells field
#
# Reading transportProperties
#
# Selecting incompressible transport model Newtonian
# Selecting incompressible transport model Newtonian
# Selecting turbulence model type RAS
# Selecting RAS turbulence model kEpsilon
# RAS
# {
#     RASModel        kEpsilon;
#     turbulence      on;
#     printCoeffs     on;
#     Cmu             0.09;
#     C1              1.44;
#     C2              1.92;
#     C3              0;
#     sigmak          1;
#     sigmaEps        1.3;
# }
#
#
# Reading g
#
# Reading hRef
# Calculating field g.h
#
# No MRF models present
#
# yPlus yPlus write:
#     writing field yPlus
#     patch left_1 y+ : min = 88.59231, max = 1327.299, average = 187.9226
#     patch bottom_1 y+ : min = 1304.21, max = 6087.204, average = 1486.538
#     patch right_3 y+ : min = 88.5923, max = 1327.299, average = 187.9226
#     patch bottom_3 y+ : min = 1304.21, max = 6087.185, average = 1486.537
#     patch left_4 y+ : min = 1305.588, max = 17781.94, average = 2605.63
#     patch right_4 y+ : min = 1305.588, max = 17781.94, average = 2605.63
#     patch bottom_4 y+ : min = 1305.588, max = 1306.472, average = 1305.61
#     patch movingObject y+ : min = 1326.366, max = 42919.92, average = 8014.948
#
# Time = 0.07
# Reading field p_rgh
#
# Reading field U
#
# Reading/calculating face flux field phi
#
# Creating cellMask field to block out hole cells
#
# Creating interpolatedCells field
#
# Reading transportProperties
#
# Selecting incompressible transport model Newtonian
# Selecting incompressible transport model Newtonian
# Selecting turbulence model type RAS
# Selecting RAS turbulence model kEpsilon
# RAS
# {
#     RASModel        kEpsilon;
#     turbulence      on;
#     printCoeffs     on;
#     Cmu             0.09;
#     C1              1.44;
#     C2              1.92;
#     C3              0;
#     sigmak          1;
#     sigmaEps        1.3;
# }
#
#
# Reading g
#
# Reading hRef
# Calculating field g.h
#
# No MRF models present
#
# yPlus yPlus write:
#     writing field yPlus
#     patch left_1 y+ : min = 87.91272, max = 1318.56, average = 186.5843
#     patch bottom_1 y+ : min = 1293.721, max = 6271.419, average = 1481.167
#     patch right_3 y+ : min = 87.91272, max = 1318.56, average = 186.5842
#     patch bottom_3 y+ : min = 1293.721, max = 6271.408, average = 1481.167
#     patch left_4 y+ : min = 1295.42, max = 18830.49, average = 2552.565
#     patch right_4 y+ : min = 1295.42, max = 18830.49, average = 2552.566
#     patch bottom_4 y+ : min = 1295.42, max = 1296.553, average = 1295.449
#     patch movingObject y+ : min = 1322.178, max = 45372.07, average = 7509.204
#
# Time = 0.08
# Reading field p_rgh
#
# Reading field U
#
# Reading/calculating face flux field phi
#
# Creating cellMask field to block out hole cells
#
# Creating interpolatedCells field
#
# Reading transportProperties
#
# Selecting incompressible transport model Newtonian
# Selecting incompressible transport model Newtonian
# Selecting turbulence model type RAS
# Selecting RAS turbulence model kEpsilon
# RAS
# {
#     RASModel        kEpsilon;
#     turbulence      on;
#     printCoeffs     on;
#     Cmu             0.09;
#     C1              1.44;
#     C2              1.92;
#     C3              0;
#     sigmak          1;
#     sigmaEps        1.3;
# }
#
#
# Reading g
#
# Reading hRef
# Calculating field g.h
#
# No MRF models present
#
# yPlus yPlus write:
#     writing field yPlus
#     patch left_1 y+ : min = 87.26846, max = 1310.011, average = 185.2651
#     patch bottom_1 y+ : min = 1283.307, max = 5665.292, average = 1461.909
#     patch right_3 y+ : min = 87.26845, max = 1310.011, average = 185.265
#     patch bottom_3 y+ : min = 1283.307, max = 5665.289, average = 1461.909
#     patch left_4 y+ : min = 1285.387, max = 18512.52, average = 2485.898
#     patch right_4 y+ : min = 1285.387, max = 18512.51, average = 2485.899
#     patch bottom_4 y+ : min = 1285.387, max = 1286.783, average = 1285.422
#     patch movingObject y+ : min = 1315.711, max = 37544.41, average = 6972.941
#
# Time = 0.09
# Reading field p_rgh
#
# Reading field U
#
# Reading/calculating face flux field phi
#
# Creating cellMask field to block out hole cells
#
# Creating interpolatedCells field
#
# Reading transportProperties
#
# Selecting incompressible transport model Newtonian
# Selecting incompressible transport model Newtonian
# Selecting turbulence model type RAS
# Selecting RAS turbulence model kEpsilon
# RAS
# {
#     RASModel        kEpsilon;
#     turbulence      on;
#     printCoeffs     on;
#     Cmu             0.09;
#     C1              1.44;
#     C2              1.92;
#     C3              0;
#     sigmak          1;
#     sigmaEps        1.3;
# }
#
#
# Reading g
#
# Reading hRef
# Calculating field g.h
#
# No MRF models present
#
# yPlus yPlus write:
#     writing field yPlus
#     patch left_1 y+ : min = 86.65552, max = 1301.601, average = 183.9739
#     patch bottom_1 y+ : min = 1272.984, max = 5531.076, average = 1451.316
#     patch right_3 y+ : min = 86.65551, max = 1301.601, average = 183.9739
#     patch bottom_3 y+ : min = 1272.984, max = 5531.074, average = 1451.316
#     patch left_4 y+ : min = 1275.488, max = 17353.19, average = 2434.657
#     patch right_4 y+ : min = 1275.488, max = 17353.15, average = 2434.658
#     patch bottom_4 y+ : min = 1275.488, max = 1277.158, average = 1275.53
#     patch movingObject y+ : min = 1308.19, max = 29662.51, average = 6562.89
#
# Time = 0.1
# Reading field p_rgh
#
# Reading field U
#
# Reading/calculating face flux field phi
#
# Creating cellMask field to block out hole cells
#
# Creating interpolatedCells field
#
# Reading transportProperties
#
# Selecting incompressible transport model Newtonian
# Selecting incompressible transport model Newtonian
# Selecting turbulence model type RAS
# Selecting RAS turbulence model kEpsilon
# RAS
# {
#     RASModel        kEpsilon;
#     turbulence      on;
#     printCoeffs     on;
#     Cmu             0.09;
#     C1              1.44;
#     C2              1.92;
#     C3              0;
#     sigmak          1;
#     sigmaEps        1.3;
# }
#
#
# Reading g
#
# Reading hRef
# Calculating field g.h
#
# No MRF models present
#
# yPlus yPlus write:
#     writing field yPlus
#     patch left_1 y+ : min = 86.02395, max = 1293.222, average = 182.6892
#     patch bottom_1 y+ : min = 1262.789, max = 5309.449, average = 1439.519
#     patch right_3 y+ : min = 86.02394, max = 1293.222, average = 182.6892
#     patch bottom_3 y+ : min = 1262.789, max = 5309.442, average = 1439.518
#     patch left_4 y+ : min = 1265.723, max = 15537.42, average = 2481.889
#     patch right_4 y+ : min = 1265.723, max = 15537.36, average = 2481.889
#     patch bottom_4 y+ : min = 1265.723, max = 1267.675, average = 1265.772
#     patch movingObject y+ : min = 1300.282, max = 24599.44, average = 6237.389
#
# Time = 0.11
# Reading field p_rgh
#
# Reading field U
#
# Reading/calculating face flux field phi
#
# Creating cellMask field to block out hole cells
#
# Creating interpolatedCells field
#
# Reading transportProperties
#
# Selecting incompressible transport model Newtonian
# Selecting incompressible transport model Newtonian
# Selecting turbulence model type RAS
# Selecting RAS turbulence model kEpsilon
# RAS
# {
#     RASModel        kEpsilon;
#     turbulence      on;
#     printCoeffs     on;
#     Cmu             0.09;
#     C1              1.44;
#     C2              1.92;
#     C3              0;
#     sigmak          1;
#     sigmaEps        1.3;
# }
#
#
# Reading g
#
# Reading hRef
# Calculating field g.h
#
# No MRF models present
#
# yPlus yPlus write:
#     writing field yPlus
#     patch left_1 y+ : min = 85.36834, max = 1284.884, average = 181.4105
#     patch bottom_1 y+ : min = 1252.726, max = 4973.987, average = 1425.681
#     patch right_3 y+ : min = 85.36833, max = 1284.884, average = 181.4105
#     patch bottom_3 y+ : min = 1252.726, max = 4973.98, average = 1425.681
#     patch left_4 y+ : min = 1256.09, max = 13398.16, average = 2690.612
#     patch right_4 y+ : min = 1256.09, max = 13398.08, average = 2690.61
#     patch bottom_4 y+ : min = 1256.09, max = 1258.331, average = 1256.147
#     patch movingObject y+ : min = 1292.231, max = 29759.51, average = 6356.141
#
# Time = 0.12
# Reading field p_rgh
#
# Reading field U
#
# Reading/calculating face flux field phi
#
# Creating cellMask field to block out hole cells
#
# Creating interpolatedCells field
#
# Reading transportProperties
#
# Selecting incompressible transport model Newtonian
# Selecting incompressible transport model Newtonian
# Selecting turbulence model type RAS
# Selecting RAS turbulence model kEpsilon
# RAS
# {
#     RASModel        kEpsilon;
#     turbulence      on;
#     printCoeffs     on;
#     Cmu             0.09;
#     C1              1.44;
#     C2              1.92;
#     C3              0;
#     sigmak          1;
#     sigmaEps        1.3;
# }
#
#
# Reading g
#
# Reading hRef
# Calculating field g.h
#
# No MRF models present
#
# yPlus yPlus write:
#     writing field yPlus
#     patch left_1 y+ : min = 84.718, max = 1276.637, average = 180.1496
#     patch bottom_1 y+ : min = 1242.78, max = 4577.184, average = 1410.666
#     patch right_3 y+ : min = 84.71799, max = 1276.637, average = 180.1496
#     patch bottom_3 y+ : min = 1242.78, max = 4577.178, average = 1410.665
#     patch left_4 y+ : min = 1246.59, max = 14636.83, average = 2995.999
#     patch right_4 y+ : min = 1246.59, max = 14636.71, average = 2995.995
#     patch bottom_4 y+ : min = 1246.589, max = 1249.122, average = 1246.654
#     patch movingObject y+ : min = 1284.01, max = 44782.64, average = 6954.005
#
# Time = 0.13
# Reading field p_rgh
#
# Reading field U
#
# Reading/calculating face flux field phi
#
# Creating cellMask field to block out hole cells
#
# Creating interpolatedCells field
#
# Reading transportProperties
#
# Selecting incompressible transport model Newtonian
# Selecting incompressible transport model Newtonian
# Selecting turbulence model type RAS
# Selecting RAS turbulence model kEpsilon
# RAS
# {
#     RASModel        kEpsilon;
#     turbulence      on;
#     printCoeffs     on;
#     Cmu             0.09;
#     C1              1.44;
#     C2              1.92;
#     C3              0;
#     sigmak          1;
#     sigmaEps        1.3;
# }
#
#
# Reading g
#
# Reading hRef
# Calculating field g.h
#
# No MRF models present
#
# yPlus yPlus write:
#     writing field yPlus
#     patch left_1 y+ : min = 84.07889, max = 1268.503, average = 178.9139
#     patch bottom_1 y+ : min = 1232.943, max = 4214.237, average = 1396.193
#     patch right_3 y+ : min = 84.07886, max = 1268.503, average = 178.9138
#     patch bottom_3 y+ : min = 1232.943, max = 4214.236, average = 1396.193
#     patch left_4 y+ : min = 1237.219, max = 16701.74, average = 3286.607
#     patch right_4 y+ : min = 1237.219, max = 16701.61, average = 3286.601
#     patch bottom_4 y+ : min = 1237.219, max = 1240.046, average = 1237.291
#     patch movingObject y+ : min = 1275.646, max = 47617.83, average = 7356.262
#
# Time = 0.14
# Reading field p_rgh
#
# Reading field U
#
# Reading/calculating face flux field phi
#
# Creating cellMask field to block out hole cells
#
# Creating interpolatedCells field
#
# Reading transportProperties
#
# Selecting incompressible transport model Newtonian
# Selecting incompressible transport model Newtonian
# Selecting turbulence model type RAS
# Selecting RAS turbulence model kEpsilon
# RAS
# {
#     RASModel        kEpsilon;
#     turbulence      on;
#     printCoeffs     on;
#     Cmu             0.09;
#     C1              1.44;
#     C2              1.92;
#     C3              0;
#     sigmak          1;
#     sigmaEps        1.3;
# }
#
#
# Reading g
#
# Reading hRef
# Calculating field g.h
#
# No MRF models present
#
# yPlus yPlus write:
#     writing field yPlus
#     patch left_1 y+ : min = 83.45351, max = 1260.57, average = 177.7085
#     patch bottom_1 y+ : min = 1223.215, max = 3948.573, average = 1383.434
#     patch right_3 y+ : min = 83.45347, max = 1260.57, average = 177.7084
#     patch bottom_3 y+ : min = 1223.215, max = 3948.567, average = 1383.434
#     patch left_4 y+ : min = 1227.976, max = 18518.9, average = 3491.434
#     patch right_4 y+ : min = 1227.976, max = 18518.77, average = 3491.427
#     patch bottom_4 y+ : min = 1227.976, max = 1231.1, average = 1228.056
#     patch movingObject y+ : min = 1267.172, max = 45530.35, average = 7421.501
#
# Time = 0.15
# Reading field p_rgh
#
# Reading field U
#
# Reading/calculating face flux field phi
#
# Creating cellMask field to block out hole cells
#
# Creating interpolatedCells field
#
# Reading transportProperties
#
# Selecting incompressible transport model Newtonian
# Selecting incompressible transport model Newtonian
# Selecting turbulence model type RAS
# Selecting RAS turbulence model kEpsilon
# RAS
# {
#     RASModel        kEpsilon;
#     turbulence      on;
#     printCoeffs     on;
#     Cmu             0.09;
#     C1              1.44;
#     C2              1.92;
#     C3              0;
#     sigmak          1;
#     sigmaEps        1.3;
# }
#
#
# Reading g
#
# Reading hRef
# Calculating field g.h
#
# No MRF models present
#
# yPlus yPlus write:
#     writing field yPlus
#     patch left_1 y+ : min = 82.83944, max = 1252.917, average = 176.533
#     patch bottom_1 y+ : min = 1213.603, max = 3783.986, average = 1372.495
#     patch right_3 y+ : min = 82.83941, max = 1252.917, average = 176.5329
#     patch bottom_3 y+ : min = 1213.603, max = 3783.97, average = 1372.494
#     patch left_4 y+ : min = 1218.861, max = 20006.95, average = 3613.113
#     patch right_4 y+ : min = 1218.861, max = 20006.83, average = 3613.107
#     patch bottom_4 y+ : min = 1218.861, max = 1222.281, average = 1218.948
#     patch movingObject y+ : min = 1258.625, max = 42099.15, average = 7283.241
#
# Time = 0.16
# Reading field p_rgh
#
# Reading field U
#
# Reading/calculating face flux field phi
#
# Creating cellMask field to block out hole cells
#
# Creating interpolatedCells field
#
# Reading transportProperties
#
# Selecting incompressible transport model Newtonian
# Selecting incompressible transport model Newtonian
# Selecting turbulence model type RAS
# Selecting RAS turbulence model kEpsilon
# RAS
# {
#     RASModel        kEpsilon;
#     turbulence      on;
#     printCoeffs     on;
#     Cmu             0.09;
#     C1              1.44;
#     C2              1.92;
#     C3              0;
#     sigmak          1;
#     sigmaEps        1.3;
# }
#
#
# Reading g
#
# Reading hRef
# Calculating field g.h
#
# No MRF models present
#
# yPlus yPlus write:
#     writing field yPlus
#     patch left_1 y+ : min = 82.23494, max = 1245.401, average = 175.3844
#     patch bottom_1 y+ : min = 1204.108, max = 3720.305, average = 1363.373
#     patch right_3 y+ : min = 82.23492, max = 1245.4, average = 175.3844
#     patch bottom_3 y+ : min = 1204.108, max = 3720.284, average = 1363.372
#     patch left_4 y+ : min = 1209.87, max = 21191.13, average = 3717.157
#     patch right_4 y+ : min = 1209.87, max = 21191.01, average = 3717.154
#     patch bottom_4 y+ : min = 1209.87, max = 1213.586, average = 1209.965
#     patch movingObject y+ : min = 1250.036, max = 39466.78, average = 7084.243
#
# Time = 0.17
# Reading field p_rgh
#
# Reading field U
#
# Reading/calculating face flux field phi
#
# Creating cellMask field to block out hole cells
#
# Creating interpolatedCells field
#
# Reading transportProperties
#
# Selecting incompressible transport model Newtonian
# Selecting incompressible transport model Newtonian
# Selecting turbulence model type RAS
# Selecting RAS turbulence model kEpsilon
# RAS
# {
#     RASModel        kEpsilon;
#     turbulence      on;
#     printCoeffs     on;
#     Cmu             0.09;
#     C1              1.44;
#     C2              1.92;
#     C3              0;
#     sigmak          1;
#     sigmaEps        1.3;
# }
#
#
# Reading g
#
# Reading hRef
# Calculating field g.h
#
# No MRF models present
#
# yPlus yPlus write:
#     writing field yPlus
#     patch left_1 y+ : min = 81.63913, max = 1238.02, average = 174.2594
#     patch bottom_1 y+ : min = 1194.732, max = 3899.113, average = 1358.408
#     patch right_3 y+ : min = 81.63912, max = 1238.02, average = 174.2593
#     patch bottom_3 y+ : min = 1194.732, max = 3899.095, average = 1358.408
#     patch left_4 y+ : min = 1201.003, max = 23651.12, average = 3864.354
#     patch right_4 y+ : min = 1201.003, max = 23651.39, average = 3864.357
#     patch bottom_4 y+ : min = 1201.003, max = 1205.012, average = 1201.105
#     patch movingObject y+ : min = 1241.435, max = 38218.65, average = 6910.475
#
# Time = 0.18
# Reading field p_rgh
#
# Reading field U
#
# Reading/calculating face flux field phi
#
# Creating cellMask field to block out hole cells
#
# Creating interpolatedCells field
#
# Reading transportProperties
#
# Selecting incompressible transport model Newtonian
# Selecting incompressible transport model Newtonian
# Selecting turbulence model type RAS
# Selecting RAS turbulence model kEpsilon
# RAS
# {
#     RASModel        kEpsilon;
#     turbulence      on;
#     printCoeffs     on;
#     Cmu             0.09;
#     C1              1.44;
#     C2              1.92;
#     C3              0;
#     sigmak          1;
#     sigmaEps        1.3;
# }
#
#
# Reading g
#
# Reading hRef
# Calculating field g.h
#
# No MRF models present
#
# yPlus yPlus write:
#     writing field yPlus
#     patch left_1 y+ : min = 81.05149, max = 1230.778, average = 173.1551
#     patch bottom_1 y+ : min = 1185.472, max = 4803.354, average = 1365.741
#     patch right_3 y+ : min = 81.05145, max = 1230.778, average = 173.1548
#     patch bottom_3 y+ : min = 1185.472, max = 4803.354, average = 1365.741
#     patch left_4 y+ : min = 1192.257, max = 32758.01, average = 4044.713
#     patch right_4 y+ : min = 1192.257, max = 32758.47, average = 4044.722
#     patch bottom_4 y+ : min = 1192.257, max = 1196.558, average = 1192.367
#     patch movingObject y+ : min = 1232.839, max = 38510.04, average = 6805.383
#
# Time = 0.19
# Reading field p_rgh
#
# Reading field U
#
# Reading/calculating face flux field phi
#
# Creating cellMask field to block out hole cells
#
# Creating interpolatedCells field
#
# Reading transportProperties
#
# Selecting incompressible transport model Newtonian
# Selecting incompressible transport model Newtonian
# Selecting turbulence model type RAS
# Selecting RAS turbulence model kEpsilon
# RAS
# {
#     RASModel        kEpsilon;
#     turbulence      on;
#     printCoeffs     on;
#     Cmu             0.09;
#     C1              1.44;
#     C2              1.92;
#     C3              0;
#     sigmak          1;
#     sigmaEps        1.3;
# }
#
#
# Reading g
#
# Reading hRef
# Calculating field g.h
#
# No MRF models present
#
# yPlus yPlus write:
#     writing field yPlus
#     patch left_1 y+ : min = 80.47254, max = 1223.68, average = 172.0676
#     patch bottom_1 y+ : min = 1176.327, max = 6748.165, average = 1390.994
#     patch right_3 y+ : min = 80.47246, max = 1223.679, average = 172.0669
#     patch bottom_3 y+ : min = 1176.327, max = 6748.216, average = 1390.994
#     patch left_4 y+ : min = 1183.631, max = 40423.22, average = 4221.317
#     patch right_4 y+ : min = 1183.631, max = 40423.7, average = 4221.332
#     patch bottom_4 y+ : min = 1183.631, max = 1188.221, average = 1183.748
#     patch movingObject y+ : min = 1224.264, max = 39914.24, average = 6769.674
#
# Time = 0.2
# Reading field p_rgh
#
# Reading field U
#
# Reading/calculating face flux field phi
#
# Creating cellMask field to block out hole cells
#
# Creating interpolatedCells field
#
# Reading transportProperties
#
# Selecting incompressible transport model Newtonian
# Selecting incompressible transport model Newtonian
# Selecting turbulence model type RAS
# Selecting RAS turbulence model kEpsilon
# RAS
# {
#     RASModel        kEpsilon;
#     turbulence      on;
#     printCoeffs     on;
#     Cmu             0.09;
#     C1              1.44;
#     C2              1.92;
#     C3              0;
#     sigmak          1;
#     sigmaEps        1.3;
# }
#
#
# Reading g
#
# Reading hRef
# Calculating field g.h
#
# No MRF models present
#
# yPlus yPlus write:
#     writing field yPlus
#     patch left_1 y+ : min = 79.90173, max = 1216.729, average = 170.9889
#     patch bottom_1 y+ : min = 1167.294, max = 9215.446, average = 1426.272
#     patch right_3 y+ : min = 79.90157, max = 1216.729, average = 170.9875
#     patch bottom_3 y+ : min = 1167.294, max = 9215.541, average = 1426.274
#     patch left_4 y+ : min = 1175.122, max = 45463.59, average = 4361.795
#     patch right_4 y+ : min = 1175.122, max = 45464.04, average = 4361.812
#     patch bottom_4 y+ : min = 1175.122, max = 1179.998, average = 1175.247
#     patch movingObject y+ : min = 1215.72, max = 41448.81, average = 6772.255
#
# Time = 0.21
# Reading field p_rgh
#
# Reading field U
#
# Reading/calculating face flux field phi
#
# Creating cellMask field to block out hole cells
#
# Creating interpolatedCells field
#
# Reading transportProperties
#
# Selecting incompressible transport model Newtonian
# Selecting incompressible transport model Newtonian
# Selecting turbulence model type RAS
# Selecting RAS turbulence model kEpsilon
# RAS
# {
#     RASModel        kEpsilon;
#     turbulence      on;
#     printCoeffs     on;
#     Cmu             0.09;
#     C1              1.44;
#     C2              1.92;
#     C3              0;
#     sigmak          1;
#     sigmaEps        1.3;
# }
#
#
# Reading g
#
# Reading hRef
# Calculating field g.h
#
# No MRF models present
#
# yPlus yPlus write:
#     writing field yPlus
#     patch left_1 y+ : min = 79.3386, max = 1209.932, average = 169.9057
#     patch bottom_1 y+ : min = 1158.37, max = 11440.76, average = 1459.318
#     patch right_3 y+ : min = 79.33838, max = 1209.932, average = 169.9036
#     patch bottom_3 y+ : min = 1158.37, max = 11440.86, average = 1459.32
#     patch left_4 y+ : min = 1166.729, max = 47972.88, average = 4443.716
#     patch right_4 y+ : min = 1166.729, max = 47973.22, average = 4443.733
#     patch bottom_4 y+ : min = 1166.729, max = 1171.886, average = 1166.861
#     patch movingObject y+ : min = 1207.216, max = 42305.56, average = 6766.429
#
# Time = 0.22
# Reading field p_rgh
#
# Reading field U
#
# Reading/calculating face flux field phi
#
# Creating cellMask field to block out hole cells
#
# Creating interpolatedCells field
#
# Reading transportProperties
#
# Selecting incompressible transport model Newtonian
# Selecting incompressible transport model Newtonian
# Selecting turbulence model type RAS
# Selecting RAS turbulence model kEpsilon
# RAS
# {
#     RASModel        kEpsilon;
#     turbulence      on;
#     printCoeffs     on;
#     Cmu             0.09;
#     C1              1.44;
#     C2              1.92;
#     C3              0;
#     sigmak          1;
#     sigmaEps        1.3;
# }
#
#
# Reading g
#
# Reading hRef
# Calculating field g.h
#
# No MRF models present
#
# yPlus yPlus write:
#     writing field yPlus
#     patch left_1 y+ : min = 78.78293, max = 1203.293, average = 168.7922
#     patch bottom_1 y+ : min = 1149.553, max = 13017.25, average = 1482.746
#     patch right_3 y+ : min = 78.78264, max = 1203.293, average = 168.7894
#     patch bottom_3 y+ : min = 1149.553, max = 13017.33, average = 1482.748
#     patch left_4 y+ : min = 1158.45, max = 48663.96, average = 4459.679
#     patch right_4 y+ : min = 1158.45, max = 48664.16, average = 4459.696
#     patch bottom_4 y+ : min = 1158.45, max = 1163.885, average = 1158.589
#     patch movingObject y+ : min = 1198.759, max = 42309.95, average = 6729.25
#
# Time = 0.23
# Reading field p_rgh
#
# Reading field U
#
# Reading/calculating face flux field phi
#
# Creating cellMask field to block out hole cells
#
# Creating interpolatedCells field
#
# Reading transportProperties
#
# Selecting incompressible transport model Newtonian
# Selecting incompressible transport model Newtonian
# Selecting turbulence model type RAS
# Selecting RAS turbulence model kEpsilon
# RAS
# {
#     RASModel        kEpsilon;
#     turbulence      on;
#     printCoeffs     on;
#     Cmu             0.09;
#     C1              1.44;
#     C2              1.92;
#     C3              0;
#     sigmak          1;
#     sigmaEps        1.3;
# }
#
#
# Reading g
#
# Reading hRef
# Calculating field g.h
#
# No MRF models present
#
# yPlus yPlus write:
#     writing field yPlus
#     patch left_1 y+ : min = 78.23463, max = 1196.814, average = 167.5921
#     patch bottom_1 y+ : min = 1140.839, max = 13914.58, average = 1494.919
#     patch right_3 y+ : min = 78.23429, max = 1196.814, average = 167.5886
#     patch bottom_3 y+ : min = 1140.839, max = 13914.63, average = 1494.92
#     patch left_4 y+ : min = 1150.282, max = 48224.81, average = 4417.971
#     patch right_4 y+ : min = 1150.282, max = 48224.96, average = 4417.988
#     patch bottom_4 y+ : min = 1150.282, max = 1155.991, average = 1150.429
#     patch movingObject y+ : min = 1190.354, max = 41721.97, average = 6656.132
#
# Time = 0.24
# Reading field p_rgh
#
# Reading field U
#
# Reading/calculating face flux field phi
#
# Creating cellMask field to block out hole cells
#
# Creating interpolatedCells field
#
# Reading transportProperties
#
# Selecting incompressible transport model Newtonian
# Selecting incompressible transport model Newtonian
# Selecting turbulence model type RAS
# Selecting RAS turbulence model kEpsilon
# RAS
# {
#     RASModel        kEpsilon;
#     turbulence      on;
#     printCoeffs     on;
#     Cmu             0.09;
#     C1              1.44;
#     C2              1.92;
#     C3              0;
#     sigmak          1;
#     sigmaEps        1.3;
# }
#
#
# Reading g
#
# Reading hRef
# Calculating field g.h
#
# No MRF models present
#
# yPlus yPlus write:
#     writing field yPlus
#     patch left_1 y+ : min = 77.6938, max = 1190.483, average = 166.1589
#     patch bottom_1 y+ : min = 1132.228, max = 14263.06, average = 1497.156
#     patch right_3 y+ : min = 77.6934, max = 1190.483, average = 166.155
#     patch bottom_3 y+ : min = 1132.228, max = 14263.09, average = 1497.157
#     patch left_4 y+ : min = 1142.224, max = 46876.44, average = 4333.881
#     patch right_4 y+ : min = 1142.224, max = 46876.58, average = 4333.898
#     patch bottom_4 y+ : min = 1142.224, max = 1148.202, average = 1142.378
#     patch movingObject y+ : min = 1182.008, max = 40958.17, average = 6559.42
#
# Time = 0.25
# Reading field p_rgh
#
# Reading field U
#
# Reading/calculating face flux field phi
#
# Creating cellMask field to block out hole cells
#
# Creating interpolatedCells field
#
# Reading transportProperties
#
# Selecting incompressible transport model Newtonian
# Selecting incompressible transport model Newtonian
# Selecting turbulence model type RAS
# Selecting RAS turbulence model kEpsilon
# RAS
# {
#     RASModel        kEpsilon;
#     turbulence      on;
#     printCoeffs     on;
#     Cmu             0.09;
#     C1              1.44;
#     C2              1.92;
#     C3              0;
#     sigmak          1;
#     sigmaEps        1.3;
# }
#
#
# Reading g
#
# Reading hRef
# Calculating field g.h
#
# No MRF models present
#
# yPlus yPlus write:
#     writing field yPlus
#     patch left_1 y+ : min = 77.16039, max = 1184.293, average = 163.9598
#     patch bottom_1 y+ : min = 1123.717, max = 14202.84, average = 1491.447
#     patch right_3 y+ : min = 77.15988, max = 1184.293, average = 163.9557
#     patch bottom_3 y+ : min = 1123.717, max = 14202.86, average = 1491.447
#     patch left_4 y+ : min = 1134.274, max = 44800.93, average = 4223.204
#     patch right_4 y+ : min = 1134.274, max = 44801.1, average = 4223.222
#     patch bottom_4 y+ : min = 1134.274, max = 1140.517, average = 1134.434
#     patch movingObject y+ : min = 1173.727, max = 40398.16, average = 6461.77
#
# Time = 0.26
# Reading field p_rgh
#
# Reading field U
#
# Reading/calculating face flux field phi
#
# Creating cellMask field to block out hole cells
#
# Creating interpolatedCells field
#
# Reading transportProperties
#
# Selecting incompressible transport model Newtonian
# Selecting incompressible transport model Newtonian
# Selecting turbulence model type RAS
# Selecting RAS turbulence model kEpsilon
# RAS
# {
#     RASModel        kEpsilon;
#     turbulence      on;
#     printCoeffs     on;
#     Cmu             0.09;
#     C1              1.44;
#     C2              1.92;
#     C3              0;
#     sigmak          1;
#     sigmaEps        1.3;
# }
#
#
# Reading g
#
# Reading hRef
# Calculating field g.h
#
# No MRF models present
#
# yPlus yPlus write:
#     writing field yPlus
#     patch left_1 y+ : min = 76.63474, max = 1178.235, average = 162.7225
#     patch bottom_1 y+ : min = 1115.304, max = 13846.65, average = 1479.657
#     patch right_3 y+ : min = 76.63405, max = 1178.235, average = 162.7173
#     patch bottom_3 y+ : min = 1115.304, max = 13846.68, average = 1479.658
#     patch left_4 y+ : min = 1126.429, max = 42256.11, average = 4098.832
#     patch right_4 y+ : min = 1126.429, max = 42256.28, average = 4098.849
#     patch bottom_4 y+ : min = 1126.429, max = 1132.933, average = 1126.597
#     patch movingObject y+ : min = 1165.512, max = 40341.68, average = 6388.398
#
# Time = 0.27
# Reading field p_rgh
#
# Reading field U
#
# Reading/calculating face flux field phi
#
# Creating cellMask field to block out hole cells
#
# Creating interpolatedCells field
#
# Reading transportProperties
#
# Selecting incompressible transport model Newtonian
# Selecting incompressible transport model Newtonian
# Selecting turbulence model type RAS
# Selecting RAS turbulence model kEpsilon
# RAS
# {
#     RASModel        kEpsilon;
#     turbulence      on;
#     printCoeffs     on;
#     Cmu             0.09;
#     C1              1.44;
#     C2              1.92;
#     C3              0;
#     sigmak          1;
#     sigmaEps        1.3;
# }
#
#
# Reading g
#
# Reading hRef
# Calculating field g.h
#
# No MRF models present
#
# yPlus yPlus write:
#     writing field yPlus
#     patch left_1 y+ : min = 76.11697, max = 1172.294, average = 162.0125
#     patch bottom_1 y+ : min = 1106.99, max = 13295.36, average = 1463.645
#     patch right_3 y+ : min = 76.11596, max = 1172.294, average = 162.0058
#     patch bottom_3 y+ : min = 1106.99, max = 13295.39, average = 1463.645
#     patch left_4 y+ : min = 1118.689, max = 39528.49, average = 3973.83
#     patch right_4 y+ : min = 1118.689, max = 39528.67, average = 3973.848
#     patch bottom_4 y+ : min = 1118.689, max = 1125.447, average = 1118.863
#     patch movingObject y+ : min = 1157.21, max = 40857.17, average = 6360.157
#
# Time = 0.28
# Reading field p_rgh
#
# Reading field U
#
# Reading/calculating face flux field phi
#
# Creating cellMask field to block out hole cells
#
# Creating interpolatedCells field
#
# Reading transportProperties
#
# Selecting incompressible transport model Newtonian
# Selecting incompressible transport model Newtonian
# Selecting turbulence model type RAS
# Selecting RAS turbulence model kEpsilon
# RAS
# {
#     RASModel        kEpsilon;
#     turbulence      on;
#     printCoeffs     on;
#     Cmu             0.09;
#     C1              1.44;
#     C2              1.92;
#     C3              0;
#     sigmak          1;
#     sigmaEps        1.3;
# }
#
#
# Reading g
#
# Reading hRef
# Calculating field g.h
#
# No MRF models present
#
# yPlus yPlus write:
#     writing field yPlus
#     patch left_1 y+ : min = 75.60729, max = 1166.463, average = 161.3396
#     patch bottom_1 y+ : min = 1098.773, max = 12648.38, average = 1445.345
#     patch right_3 y+ : min = 75.60578, max = 1166.463, average = 161.3296
#     patch bottom_3 y+ : min = 1098.773, max = 12648.42, average = 1445.346
#     patch left_4 y+ : min = 1111.051, max = 36860.9, average = 3854.789
#     patch right_4 y+ : min = 1111.051, max = 36861.1, average = 3854.807
#     patch bottom_4 y+ : min = 1111.051, max = 1118.06, average = 1111.232
#     patch movingObject y+ : min = 1148.77, max = 41929.81, average = 6388.931
#
# Time = 0.29
# Reading field p_rgh
#
# Reading field U
#
# Reading/calculating face flux field phi
#
# Creating cellMask field to block out hole cells
#
# Creating interpolatedCells field
#
# Reading transportProperties
#
# Selecting incompressible transport model Newtonian
# Selecting incompressible transport model Newtonian
# Selecting turbulence model type RAS
# Selecting RAS turbulence model kEpsilon
# RAS
# {
#     RASModel        kEpsilon;
#     turbulence      on;
#     printCoeffs     on;
#     Cmu             0.09;
#     C1              1.44;
#     C2              1.92;
#     C3              0;
#     sigmak          1;
#     sigmaEps        1.3;
# }
#
#
# Reading g
#
# Reading hRef
# Calculating field g.h
#
# No MRF models present
#
# yPlus yPlus write:
#     writing field yPlus
#     patch left_1 y+ : min = 75.10567, max = 1160.733, average = 160.7027
#     patch bottom_1 y+ : min = 1090.653, max = 11978.8, average = 1426.276
#     patch right_3 y+ : min = 75.10344, max = 1160.732, average = 160.6872
#     patch bottom_3 y+ : min = 1090.653, max = 11978.84, average = 1426.276
#     patch left_4 y+ : min = 1103.513, max = 34441.78, average = 3743.343
#     patch right_4 y+ : min = 1103.513, max = 34441.99, average = 3743.361
#     patch bottom_4 y+ : min = 1103.513, max = 1110.767, average = 1103.7
#     patch movingObject y+ : min = 1140.211, max = 43471.18, average = 6470.57
#
# Time = 0.3
# Reading field p_rgh
#
# Reading field U
#
# Reading/calculating face flux field phi
#
# Creating cellMask field to block out hole cells
#
# Creating interpolatedCells field
#
# Reading transportProperties
#
# Selecting incompressible transport model Newtonian
# Selecting incompressible transport model Newtonian
# Selecting turbulence model type RAS
# Selecting RAS turbulence model kEpsilon
# RAS
# {
#     RASModel        kEpsilon;
#     turbulence      on;
#     printCoeffs     on;
#     Cmu             0.09;
#     C1              1.44;
#     C2              1.92;
#     C3              0;
#     sigmak          1;
#     sigmaEps        1.3;
# }
#
#
# Reading g
#
# Reading hRef
# Calculating field g.h
#
# No MRF models present
#
# yPlus yPlus write:
#     writing field yPlus
#     patch left_1 y+ : min = 74.61235, max = 1155.091, average = 160.1004
#     patch bottom_1 y+ : min = 1082.629, max = 11332.26, average = 1407.443
#     patch right_3 y+ : min = 74.60925, max = 1155.09, average = 160.0776
#     patch bottom_3 y+ : min = 1082.63, max = 11332.3, average = 1407.444
#     patch left_4 y+ : min = 1096.073, max = 32357.85, average = 3642.502
#     patch right_4 y+ : min = 1096.073, max = 32358.07, average = 3642.52
#     patch bottom_4 y+ : min = 1096.073, max = 1103.568, average = 1096.267
#     patch movingObject y+ : min = 1131.547, max = 44882.43, average = 6588.585
#
# Time = 0.31
# Reading field p_rgh
#
# Reading field U
#
# Reading/calculating face flux field phi
#
# Creating cellMask field to block out hole cells
#
# Creating interpolatedCells field
#
# Reading transportProperties
#
# Selecting incompressible transport model Newtonian
# Selecting incompressible transport model Newtonian
# Selecting turbulence model type RAS
# Selecting RAS turbulence model kEpsilon
# RAS
# {
#     RASModel        kEpsilon;
#     turbulence      on;
#     printCoeffs     on;
#     Cmu             0.09;
#     C1              1.44;
#     C2              1.92;
#     C3              0;
#     sigmak          1;
#     sigmaEps        1.3;
# }
#
#
# Reading g
#
# Reading hRef
# Calculating field g.h
#
# No MRF models present
#
# yPlus yPlus write:
#     writing field yPlus
#     patch left_1 y+ : min = 74.12735, max = 1149.469, average = 159.5332
#     patch bottom_1 y+ : min = 1074.602, max = 10735.7, average = 1389.456
#     patch right_3 y+ : min = 74.12342, max = 1149.468, average = 159.5019
#     patch bottom_3 y+ : min = 1074.602, max = 10735.74, average = 1389.456
#     patch left_4 y+ : min = 1088.731, max = 30648.29, average = 3553.13
#     patch right_4 y+ : min = 1088.731, max = 30648.51, average = 3553.148
#     patch bottom_4 y+ : min = 1088.731, max = 1096.461, average = 1088.931
#     patch movingObject y+ : min = 1122.787, max = 45931.12, average = 6722.516
#
# Time = 0.32
# Reading field p_rgh
#
# Reading field U
#
# Reading/calculating face flux field phi
#
# Creating cellMask field to block out hole cells
#
# Creating interpolatedCells field
#
# Reading transportProperties
#
# Selecting incompressible transport model Newtonian
# Selecting incompressible transport model Newtonian
# Selecting turbulence model type RAS
# Selecting RAS turbulence model kEpsilon
# RAS
# {
#     RASModel        kEpsilon;
#     turbulence      on;
#     printCoeffs     on;
#     Cmu             0.09;
#     C1              1.44;
#     C2              1.92;
#     C3              0;
#     sigmak          1;
#     sigmaEps        1.3;
# }
#
#
# Reading g
#
# Reading hRef
# Calculating field g.h
#
# No MRF models present
#
# yPlus yPlus write:
#     writing field yPlus
#     patch left_1 y+ : min = 73.65067, max = 1143.779, average = 159.0052
#     patch bottom_1 y+ : min = 1066.631, max = 10199.78, average = 1372.601
#     patch right_3 y+ : min = 73.64606, max = 1143.778, average = 158.9654
#     patch bottom_3 y+ : min = 1066.631, max = 10199.83, average = 1372.601
#     patch left_4 y+ : min = 1081.483, max = 29414.16, average = 3484.243
#     patch right_4 y+ : min = 1081.483, max = 29414.41, average = 3484.259
#     patch bottom_4 y+ : min = 1081.483, max = 1089.443, average = 1081.689
#     patch movingObject y+ : min = 1113.942, max = 46516.25, average = 6854.596
#
# Time = 0.33
# Reading field p_rgh
#
# Reading field U
#
# Reading/calculating face flux field phi
#
# Creating cellMask field to block out hole cells
#
# Creating interpolatedCells field
#
# Reading transportProperties
#
# Selecting incompressible transport model Newtonian
# Selecting incompressible transport model Newtonian
# Selecting turbulence model type RAS
# Selecting RAS turbulence model kEpsilon
# RAS
# {
#     RASModel        kEpsilon;
#     turbulence      on;
#     printCoeffs     on;
#     Cmu             0.09;
#     C1              1.44;
#     C2              1.92;
#     C3              0;
#     sigmak          1;
#     sigmaEps        1.3;
# }
#
#
# Reading g
#
# Reading hRef
# Calculating field g.h
#
# No MRF models present
#
# yPlus yPlus write:
#     writing field yPlus
#     patch left_1 y+ : min = 73.18254, max = 1138.116, average = 158.5072
#     patch bottom_1 y+ : min = 1058.747, max = 9726.062, average = 1356.957
#     patch right_3 y+ : min = 73.17724, max = 1138.114, average = 158.4592
#     patch bottom_3 y+ : min = 1058.748, max = 9726.108, average = 1356.958
#     patch left_4 y+ : min = 1074.329, max = 28559.79, average = 3491.21
#     patch right_4 y+ : min = 1074.329, max = 28560.03, average = 3491.216
#     patch bottom_4 y+ : min = 1074.329, max = 1082.515, average = 1074.541
#     patch movingObject y+ : min = 1105.022, max = 46637.24, average = 6971.588
#
# Time = 0.34
# Reading field p_rgh
#
# Reading field U
#
# Reading/calculating face flux field phi
#
# Creating cellMask field to block out hole cells
#
# Creating interpolatedCells field
#
# Reading transportProperties
#
# Selecting incompressible transport model Newtonian
# Selecting incompressible transport model Newtonian
# Selecting turbulence model type RAS
# Selecting RAS turbulence model kEpsilon
# RAS
# {
#     RASModel        kEpsilon;
#     turbulence      on;
#     printCoeffs     on;
#     Cmu             0.09;
#     C1              1.44;
#     C2              1.92;
#     C3              0;
#     sigmak          1;
#     sigmaEps        1.3;
# }
#
#
# Reading g
#
# Reading hRef
# Calculating field g.h
#
# No MRF models present
#
# yPlus yPlus write:
#     writing field yPlus
#     patch left_1 y+ : min = 72.72316, max = 1132.534, average = 158.0301
# ...
#
# Time = 9.89
# Reading field p_rgh
#
# Reading field U
#
# Reading/calculating face flux field phi
#
# Creating cellMask field to block out hole cells
#
# Creating interpolatedCells field
#
# Reading transportProperties
#
# Selecting incompressible transport model Newtonian
# Selecting incompressible transport model Newtonian
# Selecting turbulence model type RAS
# Selecting RAS turbulence model kEpsilon
# RAS
# {
#     RASModel        kEpsilon;
#     turbulence      on;
#     printCoeffs     on;
#     Cmu             0.09;
#     C1              1.44;
#     C2              1.92;
#     C3              0;
#     sigmak          1;
#     sigmaEps        1.3;
# }
#
#
# Reading g
#
# Reading hRef
# Calculating field g.h
#
# No MRF models present
#
# yPlus yPlus write:
#     writing field yPlus
#     patch left_1 y+ : min = 16.49742, max = 3975.999, average = 465.3379
#     patch bottom_1 y+ : min = 1064.223, max = 4491.271, average = 3601.194
#     patch right_3 y+ : min = 28.04323, max = 4203.071, average = 489.5827
#     patch bottom_3 y+ : min = 948.4262, max = 4088.028, average = 3480.75
#     patch left_4 y+ : min = 148.0527, max = 3869.702, average = 970.8375
#     patch right_4 y+ : min = 148.0525, max = 3384.097, average = 969.1657
#     patch bottom_4 y+ : min = 148.0524, max = 152.0719, average = 148.2389
#     patch movingObject y+ : min = 255.6904, max = 6864.879, average = 1887.624
#
# Time = 9.9
# Reading field p_rgh
#
# Reading field U
#
# Reading/calculating face flux field phi
#
# Creating cellMask field to block out hole cells
#
# Creating interpolatedCells field
#
# Reading transportProperties
#
# Selecting incompressible transport model Newtonian
# Selecting incompressible transport model Newtonian
# Selecting turbulence model type RAS
# Selecting RAS turbulence model kEpsilon
# RAS
# {
#     RASModel        kEpsilon;
#     turbulence      on;
#     printCoeffs     on;
#     Cmu             0.09;
#     C1              1.44;
#     C2              1.92;
#     C3              0;
#     sigmak          1;
#     sigmaEps        1.3;
# }
#
#
# Reading g
#
# Reading hRef
# Calculating field g.h
#
# No MRF models present
#
# yPlus yPlus write:
#     writing field yPlus
#     patch left_1 y+ : min = 16.48393, max = 3970.39, average = 464.5186
#     patch bottom_1 y+ : min = 1061.885, max = 4486.641, average = 3597.249
#     patch right_3 y+ : min = 28.00489, max = 4198.895, average = 489.0698
#     patch bottom_3 y+ : min = 948.7609, max = 4085.363, average = 3477.687
#     patch left_4 y+ : min = 147.9239, max = 3868.623, average = 969.8918
#     patch right_4 y+ : min = 147.9236, max = 3383.835, average = 968.2128
#     patch bottom_4 y+ : min = 147.9235, max = 151.936, average = 148.1098
#     patch movingObject y+ : min = 255.5337, max = 6838.322, average = 1885.914
#
# Time = 9.91
# Reading field p_rgh
#
# Reading field U
#
# Reading/calculating face flux field phi
#
# Creating cellMask field to block out hole cells
#
# Creating interpolatedCells field
#
# Reading transportProperties
#
# Selecting incompressible transport model Newtonian
# Selecting incompressible transport model Newtonian
# Selecting turbulence model type RAS
# Selecting RAS turbulence model kEpsilon
# RAS
# {
#     RASModel        kEpsilon;
#     turbulence      on;
#     printCoeffs     on;
#     Cmu             0.09;
#     C1              1.44;
#     C2              1.92;
#     C3              0;
#     sigmak          1;
#     sigmaEps        1.3;
# }
#
#
# Reading g
#
# Reading hRef
# Calculating field g.h
#
# No MRF models present
#
# yPlus yPlus write:
#     writing field yPlus
#     patch left_1 y+ : min = 16.47048, max = 3964.842, average = 463.6348
#     patch bottom_1 y+ : min = 1059.552, max = 4481.968, average = 3593.304
#     patch right_3 y+ : min = 27.96671, max = 4194.74, average = 488.5166
#     patch bottom_3 y+ : min = 949.0952, max = 4082.689, average = 3474.622
#     patch left_4 y+ : min = 147.7952, max = 3867.397, average = 968.9475
#     patch right_4 y+ : min = 147.7949, max = 3383.462, average = 967.2613
#     patch bottom_4 y+ : min = 147.7949, max = 151.8004, average = 147.9809
#     patch movingObject y+ : min = 255.3774, max = 6811.662, average = 1884.217
#
# Time = 9.92
# Reading field p_rgh
#
# Reading field U
#
# Reading/calculating face flux field phi
#
# Creating cellMask field to block out hole cells
#
# Creating interpolatedCells field
#
# Reading transportProperties
#
# Selecting incompressible transport model Newtonian
# Selecting incompressible transport model Newtonian
# Selecting turbulence model type RAS
# Selecting RAS turbulence model kEpsilon
# RAS
# {
#     RASModel        kEpsilon;
#     turbulence      on;
#     printCoeffs     on;
#     Cmu             0.09;
#     C1              1.44;
#     C2              1.92;
#     C3              0;
#     sigmak          1;
#     sigmaEps        1.3;
# }
#
#
# Reading g
#
# Reading hRef
# Calculating field g.h
#
# No MRF models present
#
# yPlus yPlus write:
#     writing field yPlus
#     patch left_1 y+ : min = 16.45705, max = 3959.36, average = 462.7875
#     patch bottom_1 y+ : min = 1057.226, max = 4477.255, average = 3589.359
#     patch right_3 y+ : min = 27.92868, max = 4190.593, average = 487.9198
#     patch bottom_3 y+ : min = 949.4287, max = 4080.001, average = 3471.553
#     patch left_4 y+ : min = 147.6667, max = 3866.004, average = 968.0048
#     patch right_4 y+ : min = 147.6665, max = 3382.98, average = 966.3113
#     patch bottom_4 y+ : min = 147.6664, max = 151.665, average = 147.8523
#     patch movingObject y+ : min = 255.2215, max = 6784.909, average = 1882.534
#
# Time = 9.93
# Reading field p_rgh
#
# Reading field U
#
# Reading/calculating face flux field phi
#
# Creating cellMask field to block out hole cells
#
# Creating interpolatedCells field
#
# Reading transportProperties
#
# Selecting incompressible transport model Newtonian
# Selecting incompressible transport model Newtonian
# Selecting turbulence model type RAS
# Selecting RAS turbulence model kEpsilon
# RAS
# {
#     RASModel        kEpsilon;
#     turbulence      on;
#     printCoeffs     on;
#     Cmu             0.09;
#     C1              1.44;
#     C2              1.92;
#     C3              0;
#     sigmak          1;
#     sigmaEps        1.3;
# }
#
#
# Reading g
#
# Reading hRef
# Calculating field g.h
#
# No MRF models present
#
# yPlus yPlus write:
#     writing field yPlus
#     patch left_1 y+ : min = 16.44366, max = 3953.941, average = 462.2166
#     patch bottom_1 y+ : min = 1054.905, max = 4472.497, average = 3585.416
#     patch right_3 y+ : min = 27.89082, max = 4186.446, average = 487.2723
#     patch bottom_3 y+ : min = 949.7612, max = 4077.294, average = 3468.481
#     patch left_4 y+ : min = 147.5386, max = 3864.452, average = 967.0635
#     patch right_4 y+ : min = 147.5383, max = 3382.428, average = 965.3629
#     patch bottom_4 y+ : min = 147.5382, max = 151.5299, average = 147.7239
#     patch movingObject y+ : min = 255.066, max = 6758.07, average = 1880.864
#
# Time = 9.94
# Reading field p_rgh
#
# Reading field U
#
# Reading/calculating face flux field phi
#
# Creating cellMask field to block out hole cells
#
# Creating interpolatedCells field
#
# Reading transportProperties
#
# Selecting incompressible transport model Newtonian
# Selecting incompressible transport model Newtonian
# Selecting turbulence model type RAS
# Selecting RAS turbulence model kEpsilon
# RAS
# {
#     RASModel        kEpsilon;
#     turbulence      on;
#     printCoeffs     on;
#     Cmu             0.09;
#     C1              1.44;
#     C2              1.92;
#     C3              0;
#     sigmak          1;
#     sigmaEps        1.3;
# }
#
#
# Reading g
#
# Reading hRef
# Calculating field g.h
#
# No MRF models present
#
# yPlus yPlus write:
#     writing field yPlus
#     patch left_1 y+ : min = 16.4303, max = 3948.582, average = 461.6483
#     patch bottom_1 y+ : min = 1052.591, max = 4467.697, average = 3581.481
#     patch right_3 y+ : min = 27.85312, max = 4182.285, average = 486.5732
#     patch bottom_3 y+ : min = 950.0923, max = 4074.561, average = 3465.407
#     patch left_4 y+ : min = 147.4106, max = 3862.749, average = 966.1236
#     patch right_4 y+ : min = 147.4103, max = 3381.956, average = 964.4164
#     patch bottom_4 y+ : min = 147.4102, max = 151.395, average = 147.5957
#     patch movingObject y+ : min = 254.9108, max = 6731.162, average = 1879.208
#
# Time = 9.95
# Reading field p_rgh
#
# Reading field U
#
# Reading/calculating face flux field phi
#
# Creating cellMask field to block out hole cells
#
# Creating interpolatedCells field
#
# Reading transportProperties
#
# Selecting incompressible transport model Newtonian
# Selecting incompressible transport model Newtonian
# Selecting turbulence model type RAS
# Selecting RAS turbulence model kEpsilon
# RAS
# {
#     RASModel        kEpsilon;
#     turbulence      on;
#     printCoeffs     on;
#     Cmu             0.09;
#     C1              1.44;
#     C2              1.92;
#     C3              0;
#     sigmak          1;
#     sigmaEps        1.3;
# }
#
#
# Reading g
#
# Reading hRef
# Calculating field g.h
#
# No MRF models present
#
# yPlus yPlus write:
#     writing field yPlus
#     patch left_1 y+ : min = 16.41697, max = 3943.282, average = 461.0754
#     patch bottom_1 y+ : min = 1050.283, max = 4462.853, average = 3577.556
#     patch right_3 y+ : min = 27.81557, max = 4178.106, average = 485.8167
#     patch bottom_3 y+ : min = 950.4219, max = 4071.793, average = 3462.331
#     patch left_4 y+ : min = 147.2828, max = 3860.9, average = 965.1852
#     patch right_4 y+ : min = 147.2826, max = 3381.553, average = 963.4719
#     patch bottom_4 y+ : min = 147.2825, max = 151.2603, average = 147.4678
#     patch movingObject y+ : min = 254.7561, max = 6704.196, average = 1877.566
#
# Time = 9.96
# Reading field p_rgh
#
# Reading field U
#
# Reading/calculating face flux field phi
#
# Creating cellMask field to block out hole cells
#
# Creating interpolatedCells field
#
# Reading transportProperties
#
# Selecting incompressible transport model Newtonian
# Selecting incompressible transport model Newtonian
# Selecting turbulence model type RAS
# Selecting RAS turbulence model kEpsilon
# RAS
# {
#     RASModel        kEpsilon;
#     turbulence      on;
#     printCoeffs     on;
#     Cmu             0.09;
#     C1              1.44;
#     C2              1.92;
#     C3              0;
#     sigmak          1;
#     sigmaEps        1.3;
# }
#
#
# Reading g
#
# Reading hRef
# Calculating field g.h
#
# No MRF models present
#
# yPlus yPlus write:
#     writing field yPlus
#     patch left_1 y+ : min = 16.40368, max = 3938.036, average = 460.4726
#     patch bottom_1 y+ : min = 1047.982, max = 4457.968, average = 3573.642
#     patch right_3 y+ : min = 27.77663, max = 4173.9, average = 484.9948
#     patch bottom_3 y+ : min = 950.7493, max = 4068.985, average = 3459.252
#     patch left_4 y+ : min = 147.1553, max = 3858.911, average = 964.2482
#     patch right_4 y+ : min = 147.1551, max = 3381.19, average = 962.5293
#     patch bottom_4 y+ : min = 147.155, max = 151.126, average = 147.3401
#     patch movingObject y+ : min = 254.6017, max = 6677.185, average = 1875.936
#
# Time = 9.97
# Reading field p_rgh
#
# Reading field U
#
# Reading/calculating face flux field phi
#
# Creating cellMask field to block out hole cells
#
# Creating interpolatedCells field
#
# Reading transportProperties
#
# Selecting incompressible transport model Newtonian
# Selecting incompressible transport model Newtonian
# Selecting turbulence model type RAS
# Selecting RAS turbulence model kEpsilon
# RAS
# {
#     RASModel        kEpsilon;
#     turbulence      on;
#     printCoeffs     on;
#     Cmu             0.09;
#     C1              1.44;
#     C2              1.92;
#     C3              0;
#     sigmak          1;
#     sigmaEps        1.3;
# }
#
#
# Reading g
#
# Reading hRef
# Calculating field g.h
#
# No MRF models present
#
# yPlus yPlus write:
#     writing field yPlus
#     patch left_1 y+ : min = 16.39041, max = 3932.84, average = 459.9124
#     patch bottom_1 y+ : min = 1045.688, max = 4453.04, average = 3569.738
#     patch right_3 y+ : min = 27.7371, max = 4169.661, average = 484.0918
#     patch bottom_3 y+ : min = 951.0745, max = 4066.133, average = 3456.171
#     patch left_4 y+ : min = 147.0281, max = 3856.788, average = 963.3126
#     patch right_4 y+ : min = 147.0278, max = 3380.847, average = 961.5884
#     patch bottom_4 y+ : min = 147.0277, max = 150.9918, average = 147.2126
#     patch movingObject y+ : min = 254.4477, max = 6650.144, average = 1874.32
#
# Time = 9.98
# Reading field p_rgh
#
# Reading field U
#
# Reading/calculating face flux field phi
#
# Creating cellMask field to block out hole cells
#
# Creating interpolatedCells field
#
# Reading transportProperties
#
# Selecting incompressible transport model Newtonian
# Selecting incompressible transport model Newtonian
# Selecting turbulence model type RAS
# Selecting RAS turbulence model kEpsilon
# RAS
# {
#     RASModel        kEpsilon;
#     turbulence      on;
#     printCoeffs     on;
#     Cmu             0.09;
#     C1              1.44;
#     C2              1.92;
#     C3              0;
#     sigmak          1;
#     sigmaEps        1.3;
# }
#
#
# Reading g
#
# Reading hRef
# Calculating field g.h
#
# No MRF models present
#
# yPlus yPlus write:
#     writing field yPlus
#     patch left_1 y+ : min = 16.37717, max = 3927.693, average = 459.3491
#     patch bottom_1 y+ : min = 1043.402, max = 4448.071, average = 3565.844
#     patch right_3 y+ : min = 27.69771, max = 4165.38, average = 483.0954
#     patch bottom_3 y+ : min = 951.3972, max = 4063.234, average = 3453.089
#     patch left_4 y+ : min = 146.9011, max = 3854.536, average = 962.3785
#     patch right_4 y+ : min = 146.9007, max = 3380.504, average = 960.6493
#     patch bottom_4 y+ : min = 146.9007, max = 150.8579, average = 147.0854
#     patch movingObject y+ : min = 254.2941, max = 6623.089, average = 1872.716
#
# Time = 9.99
# Reading field p_rgh
#
# Reading field U
#
# Reading/calculating face flux field phi
#
# Creating cellMask field to block out hole cells
#
# Creating interpolatedCells field
#
# Reading transportProperties
#
# Selecting incompressible transport model Newtonian
# Selecting incompressible transport model Newtonian
# Selecting turbulence model type RAS
# Selecting RAS turbulence model kEpsilon
# RAS
# {
#     RASModel        kEpsilon;
#     turbulence      on;
#     printCoeffs     on;
#     Cmu             0.09;
#     C1              1.44;
#     C2              1.92;
#     C3              0;
#     sigmak          1;
#     sigmaEps        1.3;
# }
#
#
# Reading g
#
# Reading hRef
# Calculating field g.h
#
# No MRF models present
#
# yPlus yPlus write:
#     writing field yPlus
#     patch left_1 y+ : min = 16.36396, max = 3922.588, average = 458.7761
#     patch bottom_1 y+ : min = 1041.123, max = 4443.065, average = 3561.96
#     patch right_3 y+ : min = 27.65845, max = 4161.047, average = 481.987
#     patch bottom_3 y+ : min = 951.7169, max = 4060.287, average = 3450.006
#     patch left_4 y+ : min = 146.7742, max = 3852.159, average = 961.4457
#     patch right_4 y+ : min = 146.7739, max = 3380.144, average = 959.7119
#     patch bottom_4 y+ : min = 146.7739, max = 150.7241, average = 146.9584
#     patch movingObject y+ : min = 254.1408, max = 6596.039, average = 1871.124
#
# Time = 10
# Reading field p_rgh
#
# Reading field U
#
# Reading/calculating face flux field phi
#
# Creating cellMask field to block out hole cells
#
# Creating interpolatedCells field
#
# Reading transportProperties
#
# Selecting incompressible transport model Newtonian
# Selecting incompressible transport model Newtonian
# Selecting turbulence model type RAS
# Selecting RAS turbulence model kEpsilon
# RAS
# {
#     RASModel        kEpsilon;
#     turbulence      on;
#     printCoeffs     on;
#     Cmu             0.09;
#     C1              1.44;
#     C2              1.92;
#     C3              0;
#     sigmak          1;
#     sigmaEps        1.3;
# }
#
#
# Reading g
#
# Reading hRef
# Calculating field g.h
#
# No MRF models present
#
# yPlus yPlus write:
#     writing field yPlus
#     patch left_1 y+ : min = 16.35079, max = 3917.523, average = 458.1977
#     patch bottom_1 y+ : min = 1038.852, max = 4438.019, average = 3558.085
#     patch right_3 y+ : min = 27.61935, max = 4156.654, average = 480.7353
#     patch bottom_3 y+ : min = 952.0335, max = 4057.291, average = 3446.922
#     patch left_4 y+ : min = 146.6476, max = 3849.662, average = 960.5143
#     patch right_4 y+ : min = 146.6473, max = 3379.753, average = 958.7762
#     patch bottom_4 y+ : min = 146.6473, max = 150.5907, average = 146.8316
#     patch movingObject y+ : min = 253.988, max = 6569.019, average = 1869.545
#
# End

# %%
import re
import pandas as pd
import matplotlib.pyplot as plt

# Define file path
log_yPlus_path = "log.yPlus"  # Update with your actual path

# Read log file
with open(log_yPlus_path, 'r') as file:
    log_data = file.readlines()

# Extract time and yPlus values for different patches
time_steps = []
patch_data = {}
current_time = None

patch_pattern = re.compile(r'patch (\S+) y\+ : min = ([\d\.]+), max = ([\d\.]+), average = ([\d\.]+)')

for line in log_data:
    time_match = re.match(r"Time = ([0-9.eE+-]+)", line)
    if time_match:
        current_time = float(time_match.group(1))
        if current_time not in time_steps:
            time_steps.append(current_time)
    else:
        patch_match = patch_pattern.search(line)
        if patch_match and current_time is not None:
            patch_name = patch_match.group(1)
            yplus_avg = float(patch_match.group(4))
            
            if patch_name not in patch_data:
                patch_data[patch_name] = []
            patch_data[patch_name].append((current_time, yplus_avg))

# Convert to DataFrame
df_list = []
for patch, values in patch_data.items():
    df = pd.DataFrame(values, columns=["Time", "yPlus"])
    df["Patch"] = patch
    df_list.append(df)

df_yplus = pd.concat(df_list, ignore_index=True)

# Save to CSV
df_yplus.to_csv("yPlus_data.csv", index=False)
print("yPlus data saved to yPlus_data.csv")

# Plot yPlus values over time for each patch
plt.figure(figsize=(10, 6))
for patch in patch_data:
    df_patch = df_yplus[df_yplus["Patch"] == patch]
    plt.plot(df_patch["Time"], df_patch["yPlus"], label=patch)

plt.xlabel("Time")
plt.ylabel("yPlus Average")
plt.title("yPlus Evolution Over Time for Different Patches")
plt.legend()
plt.grid(True)

# Show plot
plt.show()
# Out:
# yPlus data saved to yPlus_data.csv

# %%
import matplotlib.pyplot as plt

# Plot the extracted values
plt.figure(figsize=(10, 6))

plt.scatter(range(len(nCells_values)), nCells_values, label='nCells', marker='.')
plt.xlabel('Index')
plt.ylabel('Values')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[28], line 6
#       3 # Plot the extracted values
#       4 plt.figure(figsize=(10, 6))
# ----> 6 plt.scatter(range(len(nCells_values)), nCells_values, label='nCells', marker='.')
#       7 plt.xlabel('Index')
#       8 plt.ylabel('Values')
#
# NameError: name 'nCells_values' is not defined

# %%
import matplotlib.pyplot as plt

# Plot the extracted values
plt.figure(figsize=(10, 6))

plt.plot(calculated_values, label='Calculated Values', marker='.')
plt.xlabel('Index')
plt.ylabel('Values')
plt.legend()
plt.grid(True)
plt.show()
print("Max calculated value:", max(calculated_values))
print("Min calculated value:", min(calculated_values))
#save the plot at folder /images/dynamicMovementsCalculated.png
plt.savefig('analysis/dynamicMovementsCalculated.png')
plt.close()
# Out:
# Max calculated value: 11464.0
# Min calculated value: 11464.0

# %%
# Plot the extracted values
plt.figure(figsize=(10, 6))

plt.plot(interpolated_values, label='Interpolated Values', marker='.')
plt.xlabel('Index')
plt.ylabel('Values')
plt.legend()
plt.grid(True)
plt.show()
print("Max calculated value:", max(interpolated_values))
print("Min calculated value:", min(interpolated_values))
#save the plot at folder /images/dynamicMovementsInterpolated.png
plt.savefig('analysis/dynamicMovementsInterpolated.png')
# Out:
# Max calculated value: 256.0
# Min calculated value: 256.0

# %%
# Plot the extracted values
plt.figure(figsize=(10, 6))

plt.plot(hole_values, label='Hole Values', marker='.')
plt.xlabel('Index')
plt.ylabel('Values')
plt.legend()
plt.grid(True)
plt.show()
# show max and min values
print("Max calculated value:", max(hole_values))
print("Min calculated value:", min(hole_values))
#save the plot at folder /images/dynamicMovementsHoles.png
plt.savefig('analysis/dynamicMovementsHoles.png')
# Out:
# Max calculated value: 658.0
# Min calculated value: 658.0
